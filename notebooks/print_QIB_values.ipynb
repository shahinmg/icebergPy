# %%
# import melt_functions as ice_melt
import numpy as np
import xarray as xr
import scipy.io as sio
# from plot_icebergshape import plot_icebergshape
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d, interp2d
from matplotlib import cm,colors
import pickle
import geopandas as gpd
from mpl_toolkits.axes_grid1 import make_axes_locatable
import os
import pandas as pd

# %% [markdown]
# ### View JKB QIB

# %%
jkb_path = '/home/m484s199/iceberg_py/dev/outfiles/iceberg_model_output/jkb/coeff_1_urel07_test/'

jkb_list = sorted([nc for nc in os.listdir(jkb_path) if nc.endswith('nc')])
jkb_dict = {}

# %%
for i,nc in enumerate(jkb_list):
    
    Qib = xr.open_dataset(f'{coeff_1_path}{nc}')
    Qib_val = Qib.Qib.data
    date = nc[:10]
    date = pd.to_datetime(date)
    jkb_dict[date] = (Qib_val/1e9)

# %%
jkb_dict
# Out:
# {Timestamp('1990-06-15 00:00:00'): np.float64(19.099131255861618),
#  Timestamp('2001-07-07 00:00:00'): np.float64(28.3447568926405),
#  Timestamp('2015-08-23 00:00:00'): np.float64(16.82195979425379),
#  Timestamp('2019-10-29 00:00:00'): np.float64(46.729150614291825),
#  Timestamp('2020-08-16 00:00:00'): np.float64(44.47927943245047)}

# %% [markdown]
# ### View Kanger QIB

# %%
kabger_path = '/home/m484s199/iceberg_py/dev/outfiles/iceberg_model_output/kanger/coeff_1_urel07_test/'

kanger_list = sorted([nc for nc in os.listdir(kabger_path) if nc.endswith('nc')])
kanger_dict = {}

# %%
for i,nc in enumerate(kanger_list):
    
    Qib = xr.open_dataset(f'{kabger_path}{nc}')
    Qib_val = Qib.Qib.data
    date = nc[:10]
    date = pd.to_datetime(date)
    kanger_dict[date] = (Qib_val/1e9)

# %%
kanger_dict
# Out:
# {Timestamp('2001-06-15 00:00:00'): np.float64(15.478059706929763),
#  Timestamp('2016-07-13 00:00:00'): np.float64(13.089066700485384),
#  Timestamp('2019-03-04 00:00:00'): np.float64(7.449285278264352),
#  Timestamp('2020-09-12 00:00:00'): np.float64(15.184241802368705),
#  Timestamp('2024-05-14 00:00:00'): np.float64(14.134220811317196)}

# %% [markdown]
# ### View UPVK QIB

# %%
upvk_path = '/home/m484s199/iceberg_py/dev/outfiles/iceberg_model_output/upvk/coeff_1_urel07_test/'

upvk_list = sorted([nc for nc in os.listdir(upvk_path) if nc.endswith('nc')])
upvk_dict = {}

# %%
for i,nc in enumerate(upvk_list):
    
    Qib = xr.open_dataset(f'{upvk_path}{nc}')
    Qib_val = Qib.Qib.data
    date = nc[:10]
    date = pd.to_datetime(date)
    upvk_dict[date] = (Qib_val/1e9)

# %%
upvk_dict
# Out:
# {Timestamp('1998-08-25 00:00:00'): np.float64(16.36772118662299),
#  Timestamp('2001-03-27 00:00:00'): np.float64(18.09702721662292),
#  Timestamp('2018-07-31 00:00:00'): np.float64(44.541875775748686),
#  Timestamp('2022-07-10 00:00:00'): np.float64(40.14115167880609),
#  Timestamp('2023-09-15 00:00:00'): np.float64(10.561960449152256)}

# %% [markdown]
# ### View Helheim QIB

# %%
helheim_path_avg = '/home/laserglaciers/icebergPy/data/iceberg_model_output_bug_fix/helheim/avg/'

helhim_list_avg = sorted([nc for nc in os.listdir(helheim_path_avg) if nc.endswith('nc')])
helheim_dict_avg = {}

# %%
for i,nc in enumerate(helhim_list_avg):
    
    Qib = xr.open_dataset(f'{helheim_path_avg}{nc}')
    Qib_val = Qib.Qib.data
    date = nc[:10]
    date = pd.to_datetime(date)
    helheim_dict_avg[date] = (Qib_val/1e9)

# %%
helheim_dict_avg
# Out:
# {Timestamp('2016-04-24 00:00:00'): np.float64(13.117863404107261),
#  Timestamp('2018-05-04 00:00:00'): np.float64(13.822705375640679),
#  Timestamp('2020-09-03 00:00:00'): np.float64(16.067207166563183),
#  Timestamp('2023-07-27 00:00:00'): np.float64(29.668287816708965),
#  Timestamp('2024-08-22 00:00:00'): np.float64(22.908883508180924)}

# %%
helheim_path_avg_013 = '/home/laserglaciers/icebergPy/data/iceberg_model_output_bug_fix/helheim/avg_013/'

helhim_list_avg_013 = sorted([nc for nc in os.listdir(helheim_path_avg_013) if nc.endswith('nc')])
helheim_dict_avg_013 = {}

# %%
helhim_list_avg_013
# Out:
# ['2016-04-24_helheim_coeff_1_CTD_constant_UREL_13.nc',
#  '2018-05-04_helheim_coeff_1_CTD_constant_UREL_13.nc',
#  '2020-09-03_helheim_coeff_1_CTD_constant_UREL_13.nc',
#  '2023-07-27_helheim_coeff_1_CTD_constant_UREL_13.nc',
#  '2024-08-22_helheim_coeff_1_CTD_constant_UREL_13.nc']

# %%
for i,nc in enumerate(helhim_list_avg_013):
    
    Qib = xr.open_dataset(f'{helheim_path_avg_013}{nc}', engine='netcdf4')
    Qib_val = Qib.Qib.data
    date = nc[:10]
    date = pd.to_datetime(date)
    helheim_dict_avg_013[date] = (Qib_val/1e9)

# %%
helheim_dict_avg_013
# Out:
# {Timestamp('2016-04-24 00:00:00'): np.float64(13.48110216511346),
#  Timestamp('2018-05-04 00:00:00'): np.float64(14.20187792471334),
#  Timestamp('2020-09-03 00:00:00'): np.float64(16.50390755309416),
#  Timestamp('2023-07-27 00:00:00'): np.float64(30.50926829334414),
#  Timestamp('2024-08-22 00:00:00'): np.float64(23.556796559151433)}

# %%
helheim_path_max = '/home/laserglaciers/icebergPy/data/iceberg_model_output_bug_fix/helheim/max_02/'

helhim_list_max = sorted([nc for nc in os.listdir(helheim_path_max) if nc.endswith('nc')])
helheim_dict_max = {}

# %%
for i,nc in enumerate(helhim_list_max):
    
    Qib = xr.open_dataset(f'{helheim_path_max}{nc}')
    Qib_val = Qib.Qib.data
    date = nc[:10]
    date = pd.to_datetime(date)
    helheim_dict_max[date] = (Qib_val/1e9)

# %%
helheim_dict_max
# Out:
# {Timestamp('2016-04-24 00:00:00'): np.float64(25.310449504783694),
#  Timestamp('2018-05-04 00:00:00'): np.float64(26.674195675762892),
#  Timestamp('2020-09-03 00:00:00'): np.float64(31.153769801678067),
#  Timestamp('2023-07-27 00:00:00'): np.float64(57.109509759821485),
#  Timestamp('2024-08-22 00:00:00'): np.float64(44.06160722546291)}

# %%
43/313
# Out:
# 0.13738019169329074

# %%
44/110
# Out:
# 0.4

# %%
qaw = [np.float64(318.0), np.float64(106.0)]

# %%
57/qaw[1]
# Out:
# np.float64(0.5377358490566038)

# %%
57/qaw[0]
# Out:
# np.float64(0.1792452830188679)

# %%
avg_013_mean = np.mean( list(helheim_dict_avg_013.values() ) )
avg_013_mean/qaw[0]
# Out:
# np.float64(0.06179430974554499)

# %%
max_02_mean = np.mean( list(helheim_dict_max.values() ) )
max_02_mean/qaw[0]
# Out:
# np.float64(0.11591794463365347)
